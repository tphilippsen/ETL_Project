# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# import first data set
pd.set_option('max_colwidth', 200)
Population_df = pd.read_csv("Population_data.csv")

# %%
Population_df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code 2000 [YR2000]  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG      19542982
# 1  Population, total  SP.POP.TOTL         Albania          ALB       3089027
# 2  Population, total  SP.POP.TOTL         Algeria          DZA      30774621
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM         58230
# 4  Population, total  SP.POP.TOTL         Andorra          AND         66097
#
#   2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004] 2005 [YR2005]  \
# 0      19688632      21000256      22645130      23553551      24411191
# 1       3060173       3051010       3039616       3026939       3011487
# 2      31200985      31624696      32055883      32510186      32956690
# 3         58324         58177         57941         57626         57254
# 4         67820         70849         73907         76933         79826
#
# ...

# %%
print(Population_df.columns)
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
#        '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]',
#        '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]'],
#       dtype='object')

# %%
# REMOVING UNNECESSARY COLUMNS
clean_pop_df = Population_df[['Series Name', 'Country Code', '2010 [YR2010]', '2011 [YR2011]',
       '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]']].copy()

clean_pop_df.head()
# Out:
#          Series Name Country Code 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0  Population, total          AFG      28189672      29249157      30466479
# 1  Population, total          ALB       2913021       2905195       2900401
# 2  Population, total          DZA      35856344      36543541      37260563
# 3  Population, total          ASM         54849         54310         53691
# 4  Population, total          AND         71519         70567         71013
#
#   2013 [YR2013] 2014 [YR2014] 2015 [YR2015]
# 0      31541209      32716210      33753499
# 1       2895092       2889104       2880703
# 2      38000626      38760168      39543154
# 3         52995         52217         51368
# 4         71367         71621         71746

# %%
# Rename columns
renamed_pop_df = clean_pop_df.rename(columns={'2010 [YR2010]': '2010', '2011 [YR2011]': '2011',
       '2012 [YR2012]': '2012', '2013 [YR2013]': '2013', '2014 [YR2014]': '2014', '2015 [YR2015]': '2015'})
renamed_pop_df.head()
# Out:
#          Series Name Country Code      2010      2011      2012      2013  \
# 0  Population, total          AFG  28189672  29249157  30466479  31541209
# 1  Population, total          ALB   2913021   2905195   2900401   2895092
# 2  Population, total          DZA  35856344  36543541  37260563  38000626
# 3  Population, total          ASM     54849     54310     53691     52995
# 4  Population, total          AND     71519     70567     71013     71367
#
#        2014      2015
# 0  32716210  33753499
# 1   2889104   2880703
# 2  38760168  39543154
# 3     52217     51368
# 4     71621     71746

# %%
# import second data set
pd.set_option('max_colwidth', 200)
gdp_df = pd.read_excel('API_NY.GDP.MKTP.CD_DS2_en_excel_v2_4770502.xls', header=3)

# %%
gdp_df.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.129081e+10  2.180870e+10  2.370727e+10  2.821034e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040414e+10  1.112789e+10  1.194319e+10  1.267633e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2012          2013          2014  \
# ...

# %%
gdp_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
# Remove unnecessary columns
clean_gdp_df = gdp_df[['Country Name', 'Country Code', 'Indicator Name','2010', '2011', '2012', '2013', '2014', '2015']].copy()

clean_gdp_df.head()
# Out:
#                   Country Name Country Code     Indicator Name          2010  \
# 0                        Aruba          ABW  GDP (current US$)  2.453631e+09
# 1  Africa Eastern and Southern          AFE  GDP (current US$)  8.603324e+11
# 2                  Afghanistan          AFG  GDP (current US$)  1.563386e+10
# 3   Africa Western and Central          AFW  GDP (current US$)  5.971293e+11
# 4                       Angola          AGO  GDP (current US$)  8.169953e+10
#
#            2011          2012          2013          2014          2015
# 0  2.637989e+09  2.615084e+09  2.727933e+09  2.791061e+09  2.963128e+09
# 1  9.641807e+11  9.725734e+11  9.834729e+11  1.003768e+12  9.245228e+11
# 2  1.819041e+10  2.020357e+10  2.056449e+10  2.055058e+10  1.999816e+10
# 3  6.804560e+11  7.360399e+11  8.322169e+11  8.924979e+11  7.669580e+11
# 4  1.094366e+11  1.249982e+11  1.334016e+11  1.372444e+11  8.721930e+10

# %%
clean_gdp_df = clean_gdp_df.rename(columns={'Indicator Name': 'Indicator'})
clean_gdp_df
# Out:
#                     Country Name Country Code          Indicator  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#              2010          2011          2012          2013          2014  \
# 0    2.453631e+09  2.637989e+09  2.615084e+09  2.727933e+09  2.791061e+09
# ...

# %%
# Merge dataframes on country code
gdp_pop_df = pd.merge(clean_gdp_df, renamed_pop_df, on= 'Country Code', how= 'right')
gdp_pop_df.head(20)
# Out:
#            Country Name Country Code     Indicator Name        2010_x  \
# 0           Afghanistan          AFG  GDP (current US$)  1.563386e+10
# 1               Albania          ALB  GDP (current US$)  1.192692e+10
# 2               Algeria          DZA  GDP (current US$)  1.612073e+11
# 3        American Samoa          ASM  GDP (current US$)  5.730000e+08
# 4               Andorra          AND  GDP (current US$)  3.449967e+09
# 5                Angola          AGO  GDP (current US$)  8.169953e+10
# 6   Antigua and Barbuda          ATG  GDP (current US$)  1.148700e+09
# 7             Argentina          ARG  GDP (current US$)  4.236274e+11
# 8               Armenia          ARM  GDP (current US$)  9.260285e+09
# 9                 Aruba          ABW  GDP (current US$)  2.453631e+09
# 10            Australia          AUS  GDP (current US$)  1.148610e+12
# 11              Austria          AUT  GDP (current US$)  3.922751e+11
# ...

# %%
clean_gdp_df[['Indicator','Currency']] = clean_gdp_df.Indicator.str.split(expand=True)
clean_gdp_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/megphilippsen/Desktop/ETL_Project/ETL_Project.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/ETL_Project/ETL_Project.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> clean_gdp_df[['Indicator','Currency']] = clean_gdp_df.Indicator.str.split(expand=True)
#       <a href='vscode-notebook-cell:/Users/megphilippsen/Desktop/ETL_Project/ETL_Project.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> clean_gdp_df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3643, in DataFrame.__setitem__(self, key, value)
#    3641     self._setitem_frame(key, value)
#    3642 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
#    3645     self._set_item_frame_value(key, value)
#
# ...
